# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/AppliedPhysics1/blob/draft/2152_%E5%87%B8%E3%83%AC%E3%83%B3%E3%82%BA%E3%81%AB%E3%82%88%E3%82%8B%E5%AE%9F%E5%83%8F_%E5%BF%9C%E7%94%A8%E7%89%A9%E7%90%861.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 光の進み方
# ## レンズ
#
# + (対称な)レンズの真ん中を通る光線は影響を受けず直進
# + 光軸に平行な光の行く先
# + 焦点を通過/焦点へ延長される光線
#
# に注意し **図形の相似** を考えれば以下の式は導出できます.

# %% [markdown]
# ### 凸レンズによる実像

# %%
#@title 凸レンズの実像の作成方法
# %%svg
https://upload.wikimedia.org/wikipedia/commons/5/55/Lens3-ja.svg

# %% [markdown]
# #### 凸レンズの実像の倍率と物体と実像の関係式
#
# 凸レンズの **実像** は, 図で確認できるように倒立しているので,
# **倒立像** と言います.
#
# ##### 倍率
# + 物体と実像は(光源と像なので)平行(緑矢印)
# + (対称な)レンズの真ん中を通る光線は影響を受けず直進
#
# これから, 倍率 $m$ を図形的な条件を求めると,
#
# > $\qquad m = \dfrac{h_{\rm 像}}{h_{\rm 物体}} = \dfrac{S_2}{S_1}$
#
# ##### 物体と実像の関係式
# + 物体から出た光軸に平行な光
# + レンズの中心に物体と同じ高さが取れる
#
# これから, 倍率 $m$ を図形的な条件を求めると,
#
# > $\qquad m = \dfrac{h_{\rm 像}}{h_{\rm 物体}} = \dfrac{S_2 - f}{f}$
#
# これらをまとめると
# \begin{align*}
# \dfrac{S_2}{S_1} &= m = \dfrac{S_2 - f}{f}&\\
# S_2 f &= S_1 S_2 - f S_1&\\
# S_2 f + f S_1 &= S_1 S_2 &
# \end{align*}
# ここで両辺を $S_1 S_2 f$ で割ると
# \begin{align*}
# \frac{S_2 f}{S_1 S_2 f} + \frac{f S_1}{S_1 S_2 f}
# &= \frac{S_1 S_2}{S_1 S_2 f} &\\
# \end{align*}
#
# >> $\qquad \dfrac{1}{S_1} + \dfrac{1}{S_2} = \dfrac{1}{f}$
