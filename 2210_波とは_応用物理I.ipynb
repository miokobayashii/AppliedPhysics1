# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/AppliedPhysics1/blob/draft/2210_%E6%B3%A2%E3%81%A8%E3%81%AF_%E5%BF%9C%E7%94%A8%E7%89%A9%E7%90%86I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 直線上を伝わる波

# %%
#@title 光から波へ
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Iuv6hY6zsd0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Iuv6hY6zsd0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 復習: 単振動

# %%
#@title フックの法則 f= -kx. 運動方程式 f=ma
# %%html
<iframe src="https://phet.colorado.edu/sims/html/masses-and-springs/latest/masses-and-springs_en.html" width="720" height="540" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/masses-and-springs/latest/masses-and-springs_en.html" width="720" height="540" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
# ### 単振動 ~ 等速円運動の射影
# ![wikipedia: Simple Harmonic Motion Orbit](https://upload.wikimedia.org/wikipedia/commons/e/ea/Simple_Harmonic_Motion_Orbit.gif)
#
# |等速円運動|単振動|単位|
# |--|--|--|
# | 時間 $t$ | 時間 $t$ | s|
# | 半径 $r$ | 振幅 $A$| m|
# | 周期 $T$| 周期 $T$ | s|
# |回転数 $n$| 振動数 $f$| Hz = 1/s|
# |角速度 $\omega$| 角振動数 $\omega$| rad/s|
#
# #### 関係式
#
# > $\quad f\cdot T=1$
#
# #### 定義式
# > $\quad \omega = \dfrac{\theta}{t} = \dfrac{\Delta \theta }{\Delta t}$
#
# 一周を考慮すると
# > $\quad \omega = \dfrac{2\pi}{T} = 2\pi f$

# %%
#@title 三角比を用いた単振動の変位の導出
# %%svg
https://upload.wikimedia.org/wikipedia/commons/6/6f/Rtriangle.svg

# %% [markdown]
# - 斜辺の長さ $c$ を半径 $A$
# - $\angle{\rm CAB}=\theta$
#
# とすると高さ $y=a$ は, 三角比を利用し
# > $\quad y= a = A \sin \theta$
#
# ここに先に整理した $\theta = \omega t$ を代入すると
#
# > $\quad y = A\sin \left( \omega t\right)$
#
# これは $t=0$ のとき $y=0$ となるので, 原点を中心とした **単振動** になる. $\sin$ の後の括弧$\left({}\right)$の中を **位相** といいます.
#
# 一般には $t=0$ のときに, 原点に *いない* こともあるので,
# $t=0$ のときの位相 $\alpha$ を **初期位相** といいます.
#
# これより, 単振動の変位は
# >> $\qquad y = A \sin \left( \omega t + \alpha\right)$
#
# となります.

# %% [markdown]
# #### 単振動の速度
#
# 幾何学的な関係から導出することは, 物理Iの講義で確認しています(参照:教科書上巻p73-p75).
# ここでは(瞬間の)速度と(瞬間の)加速度の定義を利用して導出します.
#
# ##### 平均の速度から瞬間の速度へ
# 平均の速度 $\bar{v}$ の時間間隔 $\Delta t$ を小さくすると, 瞬間の速度になります. これは数学的には微分定義に他なりません.
# \begin{align*}
# \bar{v}_y &= \dfrac{\Delta y}{\Delta t}&\\
# v_y &=
#  \lim_{\Delta \to 0} \dfrac{\Delta y}{\Delta t}
#  = \dfrac{{\rm d\ } y}{{\rm d\ } t}&
# \end{align*}
#
# これを利用すると, 一般の単振動の変位 $y=A\sin\left(\omega + \alpha\right)$ の速度は,
#
# \begin{align*}
# v_y & = \dfrac{{\rm d\ } y}{{\rm d\ } t}
# =
# \dfrac{{\rm d\ } (\omega t + \alpha)}{{\rm d\ }t}
# \cdot
# \dfrac{{\rm d\ } y}{{\rm d\ } (\omega t + \alpha)}&\\
# &= \omega  \cdot \dfrac{{\rm d\ } \left[ A\sin\left(\omega + \alpha\right)\right]}{{\rm d\ } (\omega t + \alpha)}&\\
# &= \omega \cdot A \cos \left(\omega + \alpha\right)&
# \end{align*}
#
# >>$\quad v_y = \omega A \cos \left( \omega t + \alpha\right)$

# %% [markdown]
# #### 単振動の加速度
#
# ##### 平均の加速度から瞬間の加速度へ
# 瞬間の速度を求めたときの議論をここでも利用します.
#
# \begin{align*}
# \bar{a}_y &= \dfrac{\Delta v_y}{\Delta t}&\\
# a_y &=
#  \lim_{\Delta \to 0} \dfrac{\Delta v_y}{\Delta t}
#  = \dfrac{{\rm d\ } v_y}{{\rm d\ } t}&
# \end{align*}
#
# これを利用すると, 一般の単振動の変位 $y=A\sin\left(\omega + \alpha\right)$ と その速度 $v_y=\omega A\cos\left(\omega + \alpha\right)$  は,
#
# \begin{align*}
# a_y & = \dfrac{{\rm d\ } v_y}{{\rm d\ } t}
# =
# \dfrac{{\rm d\ } (\omega t + \alpha)}{{\rm d\ }t}
# \cdot
# \dfrac{{\rm d\ } v_y}{{\rm d\ } (\omega t + \alpha)}&\\
# &= \omega  \cdot \dfrac{{\rm d\ } \left[ \omega A\cos\left(\omega + \alpha\right)\right]}{{\rm d\ } (\omega t + \alpha)}&\\
# &= - \omega^2 \cdot A \sin \left(\omega + \alpha\right)&\\
# &= - \omega^2 y&
# \end{align*}
#
# >>$\quad a_y = - \omega^2 A \sin \left( \omega t + \alpha\right) = - \omega^2 y$

# %% [markdown]
# #### 単振動とフックの法則
#
# 単振動の変位$y$, 速度$v_y$, 加速度$a_y$ を書きにまとめると
# \begin{align*}
# y &= A \sin \left( \omega t + \alpha\right)&\\
# v_y &= \omega A \cos \left( \omega t + \alpha\right)&\\
# a_y &= - \omega^2 A \sin \left( \omega t + \alpha\right) = - \omega^2 y&
# \end{align*}
#
# 加速度 $a_y$ に質量を両辺に掛けると, 運動方程式 $ma=f$ を利用すると
# \begin{align*}
# m\cdot a_y &= - m\cdot \omega^2 y&
# \end{align*}
# ここで $m\omega^2 = k$, $F_y = m a_y$ とおくと
# \begin{align*}
# F_y &= - k y&
# \end{align*}
# この式はフックの法則 $F=-kx$ と同じ形をしている.
#
# $k=m\omega^2$ を利用すると,
# \begin{align*}
# T = \dfrac{2\pi}{\omega} = 2\pi \sqrt{\dfrac{m}{k}}
# \end{align*}

# %% [markdown]
# ## 波とは

# %% [markdown]
# ### 用語
#
# - 波動, 波: ある場所に生じた振動が次々に伝わる**現象**
# - 媒質: 振動を伝える物質
# - 波源: 最初に振動をはじめた点

# %%
#@title シミュレーション:直線状を伝わる波
# %%html
<iframe src="https://phet.colorado.edu/sims/html/wave-on-a-string/latest/wave-on-a-string_en.html" width="720" height="540" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/wave-on-a-string/latest/wave-on-a-string_en.html" width="720" height="540" scrolling="no" allowfullscreen></iframe>
