# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/AppliedPhysics1/blob/draft/1FC_043_EM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 電解質

# %% [markdown]
# ## イオンの移動度と輸率

# %% [markdown]
# ### イオンの移動度 $u$
# $\require{cancel}$
# - イオン: 電荷 $z$, 半径 $a$ in 電場 $E\ {\rm (Vm^{-1})}$
# - イオンに働く力: $\qquad f_e= z e E$
# - イオンの速度: $s$
# - イオンに働く抵抗 ~ Stoke's law: $\quad f_{\rm f}=6 \pi \eta a s$
#
# $\eta\ {\rm (Pa\ s)}$: 粘性係数
#
# これらをもとにイオンの運動方程式を立て, 十分時間が経過した状況では速度は変化しないので
# \begin{align*}
# m \cancelto{0}{\dfrac{{\rm d}s}{{\rm d}t}} &= f_e - f_{\rm f}&\\
# \end{align*}
# これを整理すると **ドリフト速度 $s$**
# \begin{align*}
# s &= \dfrac{z e E}{6 \pi \eta a},
# \end{align*}
# が得られ, これを単位電場あたりに換算したものを **移動度 $u$**
# \begin{align*}
# u&= \dfrac{s}{E} = \dfrac{z e}{6 \pi \eta a}
# \propto
# \begin{cases}
# z&\\
# \dfrac{1}{\eta}&\\
# \dfrac{1}{a}&
# \end{cases}&
# \end{align*}

# %% [markdown]
# $\require{mhchem}$
# ### 移動度による極限モル伝導率 $\Lambda^\circ_{\rm m}$ の表現
#
# 電荷 $z$ を持つイオンの伝導率 $\lambda$ は
# \begin{align*}
# \lambda = q u = (z \mathcal{F}) u = z u \mathcal{F}
# \end{align*}
# $\mathcal{F}=e\cdot N_{\rm A}$: Faradday constant
#
# 次のような電解質では
# \begin{align*}
# \ce{A}_{\nu_+} + \ce{B}_{\nu_-}
#  &\to
# {\nu_+} \ce{A}^{z_+}
# + {\nu_-} \ce{B}^{z_-}&
# \end{align*}
# ここで
# - $\ce{A}^{z_+}$: cation($z_+>0$),
# $\ce{B}^{z_-}$: anion($z_-<0$)
# - ${z_+}{\nu_+}+{z_-}{\nu_-}=0$
# - $u^\circ_+$: mobility of cation
#   $u^\circ_-$: mobility of anion
#
# \begin{align*}
# \Lambda^\circ_{\rm m}
# &=
# {\nu_+}\lambda^\circ_+
# +
# {\nu_-} \lambda^\circ_-&\\
# &=\left(
# {\nu_+} z_+ u^\circ_+
# +
# {\nu_-} z_- u^\circ_-
#   \right)\mathcal{F}
# \end{align*}

# %% [markdown]
# ### 輸率 $t_{\pm}$
#
# あるイオンが運ぶ電流の割合
#
# - $I_+$: cation $\ce{A}^{z_+}$ が運ぶ電流
# - $I_-$: anion $\ce{A}^{z_+}$ が運ぶ電流
# - $I = I_+ + I_-$: 全電流
#
# 輸率 $t_{\pm}$ の定義
# \begin{align*}
# t_{\pm} &= \dfrac{I_{\pm}}{I}.
# \end{align*}
# 全電流 $I$ から
# \begin{align*}
# t_+ + t_- &= 1.&
# \end{align*}
# これらを利用すると無限希釈溶液のイオン輸率
#  $t_{\pm}^\circ$ は,
#  無限希釈におけるモル伝導率を利用すれば $I=\Lambda_{\rm m}^\circ$,
#  $I_\pm={\nu_\pm}\lambda^\circ_\pm$
# \begin{align*}
# t_\pm^\circ
# &=
# \dfrac{\nu_\pm \lambda_\pm^\circ}
# {\Lambda_{\rm m}^\circ}
# =
# \dfrac{\nu_\pm \lambda_\pm^\circ}
# {{\nu_+}\lambda^\circ_+ + {\nu_-}\lambda^\circ_-}
# =
# \dfrac{\nu_\pm z_\pm u_\pm^\circ}
# {{\nu_+} z_+ u^\circ_+ + {\nu_-} z_- u^\circ_-}
# \end{align*}
# $t^\circ_\pm$ はイオンの数や種類できまる.
#
# $\require{cancel}$
# 一方(+)だけが動ける場合は
# \begin{align*}
# t_+^\circ
# &=
# \dfrac{\nu_+ z_+ u_+^\circ}
# {{\nu_+} z_+ u^\circ_+ + \cancelto{0}{{\nu_-} z_- u^\circ_-}} \to 1
# \end{align*}
