# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/AppliedPhysics1/blob/master/1107_%E7%AD%89%E5%8A%A0%E9%80%9F%E5%BA%A6%E7%9B%B4%E7%B7%9A%E9%81%8B%E5%8B%95_%E7%89%A9%E7%90%861.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 運動の表し方

# %% [markdown]
# ## 等加速度直線運動
#
# > 等加速度直線運動 = 「等」+ 「加速度」+「直線」+ 運動
# と分解し, それぞれの要素について
#
# > 「等」+ 「加速度」: 一定の **加速度**
# > 直線: (ある点から出発し)直線上を進む
#
# ### 復習: 物体の加速度 $a$ の定義
# $$
# a = \dfrac{\Delta v}{\Delta t}
# = \dfrac{v_2 - v_1 }{t_2 - t_1}
# $$

# %% [markdown]
# #### 初め静止していた等加速度直線運動の速度
#
# いま$a$ を一定, さらに
# * 測定開始時点を $t_1=0$ でこのときの速度を $v_1=0$
# * 測定開始時点 $t_1=0$ から経過した時間を $t_2=t$
#
# と置き直すと
#
#
# $$
# \require{cancel}
# \begin{align*}
# a &= \dfrac{\cancelto{v}{v_2} - \cancelto{0}{v_1}}
# {\cancelto{t}{t_2} - \cancelto{0}{t_1}}&\\
# &= \dfrac{v}{t}\\
# v&=a\cdot t&
# \end{align*}
# $$
# これより, 初め静止していた物体が, 等加速度で直線上を運動する $t$ 秒後の速度は
# >> $(1.6) \qquad v = a \cdot t$
#
# となることがわかる.
