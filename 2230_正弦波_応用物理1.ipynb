# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/AppliedPhysics1/blob/draft/2230_%E6%AD%A3%E5%BC%A6%E6%B3%A2_%E5%BF%9C%E7%94%A8%E7%89%A9%E7%90%861.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 直線上を伝わる波
#
# 1. **媒質の振幅** と **波形の伝わる** 方向に注意
# 2. 媒質は(ほとんど)移動せず(元の位置に戻ろうとし), 波形のみが伝わる

# %% [markdown]
# ## 正弦波
# ### 媒質の変位 $y$

# %%
#@title 正弦関数: y = sin (x)
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, np.sin(x), '-')
plt.grid(b=None, which='major', axis='both')

# %% [markdown]
# > Q. 上の図について, 横軸を原点からの媒質の位置(単位 m), 縦軸を媒質の変位 y (単位 m)として, 波長$\lambda$ と振幅 $A$ を求めてください.
# この波が来る前は, 媒質はどの位置でも $y=0$ とします.

# %%
#@title Q の答え
print("λ:2 π m \nA: 1 m")

# %% [markdown]
# ## 正弦波の導出: 原点の振動の遅れ

# %%
#@title 原点の振動の遅れ観察 原点の振動の遅れ観察 : (Slow Mothon + Pulse + No End + Damping:None)
: (Slow Mothon + Pulse + No End + Damping:None)
# %%html
<iframe src="https://phet.colorado.edu/sims/html/wave-on-a-string/latest/wave-on-a-string_en.html" width="720" height="540" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/wave-on-a-string/latest/wave-on-a-string_en.html" width="720" height="540" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
# 原点の振動 $y_0$ を 振幅$A$, 周期$T$, 振動数$f$ の単振動とする
# \begin{align*}
# y_0 &= A \sin \omega t = A \sin \dfrac{2\pi}{T} t = A \sin 2\pi f t &\\
# &= y_0(t)&
# \end{align*}
#
# この原点 O の振動が,
# - $x$軸 の正の向きに (一定の)速さ $v$ で伝わるとき
# - 原点 O から $x$ だけ離れた点P における 正弦波の変位 $y$ を求める.
#
# ポイントは二つ
#
# 1. 原点の振動が点P伝わるまでに伝わる時間: $\quad t' = \dfrac{x}{v}$
# 2. 点Pでの変位は, 原点Oの変位から遅れる: $\quad t-t'$
#
# これらを原点の単振動へ組み込むと,(波の基本式:$v=\frac{\lambda}{T}$)
# \begin{align*}
# y &= y_0(t-t') = A \sin \dfrac{2\pi}{T} \left( t- \dfrac{x}{v}\right)&\\
# &= A \sin 2\pi\left( \dfrac{t}{T}- \dfrac{x}{vT}\right)&\\
# &= A \sin 2\pi\left( f t - \dfrac{x}{\lambda}\right)&\\
# \end{align*}
#
# より一般化し, 原点での振動が初期位相 $\alpha$ を持ち $x$ 軸上を正の方向に伝播する正弦波の変位は次のようになります.
# \begin{align*}
# y &= A \sin \left\{ 2\pi\left(f t - \dfrac{x}{\lambda}\right)+ \alpha\right\}&\\
# \end{align*}
#
# - 位相: 括弧 $\{\}$ の中. 媒質の振動の情報をあたえます.

# %% [markdown]
# > Q. 上の解説を参考に, $x$軸上を **負の方向に** 伝播する正弦波の変位を示してください.

# %% [markdown]
# ## 正弦波の導出: 波形の拡大と平行移動

# %%
#@title y=sin(x);  y=sin(x+2π)=sin(x)
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, np.sin(x), '-')

plt.grid(b=None, which='major', axis='both',linewidth = 1)
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %%
#@title y= sin(2πx); y=sin(2π(x+1))= sin(2πx+2π) = sin(2π/1 x)
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 500)

A=1

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, A*np.sin(2*np.pi*x), '-')

plt.grid(b=None, which='major', axis='both')
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %%
#@title y= sin(2πx/λ), λ=3 m ; y= sin(2π(x+λ)/λ) = sin(2πx/λ+2π) = sin(2π/λ x)
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 100)

A=1
lmd=3

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, A*np.sin(2*np.pi*x/lmd), '-')
plt.grid(b=None, which='major', axis='both')
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %%
#@title y=A sin(2πx/λ), A=4 m, λ= 3 m; y= A sin(2π(x+λ)/λ) = A sin(2πx/λ+2π) = A sin(2π/λ x)
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 1000)

A=4
lmd=3

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, A*np.sin(2*np.pi*x/lmd), '-')
plt.grid(b=None, which='major', axis='both')
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %%
#@title y=A sin(2π/λ x), A=4 m, λ= 3 m, v=2 m/s; t 秒後に v=λ/T で右に進むと 
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 100)

(A,lmd,v)=(4,3,2)

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, A*np.sin(2*np.pi*x/lmd), linestyle='dotted')
plt.grid(b=None, which='major', axis='both')
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %%
#@title y=A sin(2π/λ x), A=4 m, λ= 3 m, v=2 m/s, 0.25 s 秒
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 100)

(A,lmd,v)=(4,3,2)

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, A*np.sin(2*np.pi*x/lmd), linestyle='dotted')
plt.plot(x, A*np.sin(2*np.pi*(x-v*0.25)/lmd), color='blue')
plt.grid(b=None, which='major', axis='both')
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %%
#@title y=A sin(2π/λ x), A=4 m, λ= 3 m, v=2 m/s, 0.50 s 秒
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick # 目盛り操作に必要なライブラリを読み込みます
import numpy as np

x = np.linspace(0, 10, 100)

(A,lmd,v)=(4,3,2)

fig = plt.figure()
plt.xlim(0, 10)
plt.ylim(-5,+5)
plt.axhline(y=0, color='k',linestyle='dashed', linewidth=0.5)
plt.plot(x, A*np.sin(2*np.pi*x/lmd), linestyle='dotted')
plt.plot(x, A*np.sin(2*np.pi*(x-v*0.50)/lmd), color='blue')
plt.grid(b=None, which='major', axis='both')
plt.gca().xaxis.set_minor_locator(tick.MultipleLocator(1))
plt.grid(which='minor', alpha=0.5)

# %% [markdown]
# 振幅 $A$, 波長 $\lambda$ で, 初期位相がない($\alpha=0$) の波形は, 上の図から
# \begin{align*}
# y_{t=0} (x) &=  A \sin \left(\dfrac{2\pi}{\lambda} x\right)&
# \end{align*}
# となります.
#
# これが速さ $v$ m/s で右向きに平行移動すると, $t$ s 後には右向きへ $v\cdot t$ 移動したことになります.
#
# これから, 速さ $v$ で進む正弦波のについて, 原点からの位置 $x$ にある媒質の時間 $t$ における媒質の変位 $y$ は
# \begin{align*}
# y(x,t) &= y_{t=0} (x-vt)=  A \sin \left\{\dfrac{2\pi}{\lambda} (x-vt)\right\}&\\
# &=  A \sin 2\pi \left(\dfrac{x}{\lambda} - \dfrac{t}{\frac{\lambda}{v}}\right)&\\
# &=A \sin 2\pi \left(\dfrac{x}{\lambda} - \dfrac{t}{T}\right)&\\
# &=A \sin 2\pi \left(\dfrac{x}{\lambda} - ft\right)&
# \end{align*}
# となります.
#
# 波形から速さ $v$ で進む一般的な正弦波のについて, 初期位相まで取り込んで
# \begin{align*}
# y&=A \sin \left\{ 2\pi \left(\dfrac{x}{\lambda} - ft\right) + \alpha \right\}&
# \end{align*}
# と書くことができます.

# %% [markdown]
# > 教科書の例題2.3,2.4 に取り組んでください.
