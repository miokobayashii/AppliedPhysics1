# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/AppliedPhysics1/blob/draft/2320_%E5%B9%B3%E9%9D%A2%E3%81%A8%E7%A9%BA%E9%96%93%E3%82%92%E4%BC%9D%E3%82%8F%E3%82%8B%E6%B3%A2%E3%81%AE%E5%B9%B2%E6%B8%89_%E5%BF%9C%E7%94%A8%E7%89%A9%E7%90%861.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 平面, 空間を伝わる波

# %% [markdown]
# ## 平面と空間を伝わる波の干渉

# %%
#@title 干渉: interference
# %%html
<iframe src="https://phet.colorado.edu/sims/html/wave-interference/latest/wave-interference_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/wave-interference/latest/wave-interference_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
# ### 波の干渉条件
#
# ![https://commons.wikimedia.org/wiki/File:Standing_wave_2.gif](https://upload.wikimedia.org/wikipedia/commons/7/7d/Standing_wave_2.gif)
#
# 1. **強め合う条件** :: 時間変化で **激しく振動する** 条件 ~ 定常波の **腹**
# 2. *弱め合う合う条件* :: 時間変化で *全く振動しない* 条件 ~ 定常波の *節*
#
# - 波源 = source of wave -> S
# - 観察点 = a point -> P or Q
#
# 簡単のために,　これから考える干渉については, **二つの波源の位相は等しい** ものとします. このような条件を
# > 波源は同位相である
#
# と言います.

# %% [markdown]
# $\require{cancel}$
# #### 強め合う条件
#
# >> ある点 P について, 二つの同位相の波源 ${\rm S_1, S_2}$からの距離の差 $\Delta L$ が **波長 $\lambda$ の整数倍**  $m$ であれば, 強め合う(腹になる)
#
# \begin{align*}
# \Delta L &= \left|\overline{\rm S_1P} - \overline{\rm S_2P}\right|
#  = m \lambda &\\
#  &= \bcancel{2} m \dfrac{\lambda}{\bcancel{2}} = 2 m \dfrac{\lambda}{2}&
# \end{align*}
#
# この関係式を
# > 波源が同位相で $\Delta L$ が 半波長 $\dfrac{\lambda}{2}$ の **偶数倍** のとき, 注目する点は腹になる
#
# と読むこともできます.

# %% [markdown]
# #### 弱め合う条件
#
# >> ある点 Q について, 二つの同位相の波源 ${\rm S_1, S_2}$からの距離の差 $\Delta L$ が波長 $\lambda$ の整数倍 $m$ から **半波長 $\dfrac{\lambda}{2}$ ずれていれば**,  弱め合う(節になる)
#
# \begin{align*}
# \Delta L &= \left|\overline{\rm S_1Q} - \overline{\rm S_2Q}\right|
#  = m \lambda + \dfrac{\lambda}{2}= \left( m + \dfrac{1}{2}\right)\lambda&\\
#  &= \left(\bcancel{2} m + 1 \right)\dfrac{\lambda}{\bcancel{2}}
#  = \left(2 m +1 \right) \dfrac{\lambda}{2}&
# \end{align*}
#
# この関係式を
# > 波源が同位相で $\Delta L$ が 半波長 $\dfrac{\lambda}{2}$ の **奇数倍* のとき, 注目する点は節になる
#
# と読むこともできます.

# %% [markdown]
# ### 波の干渉と双曲線
#
# 強め合っている点も弱めあっている点も次の関係を満たしています:
# \begin{align*}
# \Delta L &= \left|\overline{\rm S_1Q} - \overline{\rm S_2Q}\right|
# \end{align*}
# ここでは, 分かりするために近接する弱めあっている点(節)に注目しましょう.

# %%
#@title 干渉: Interference + Frequency:max + Separation:5
# %%html
<iframe src="https://phet.colorado.edu/sims/html/wave-interference/latest/wave-interference_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/wave-interference/latest/wave-interference_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
# ![https://en.wikipedia.org/wiki/File:Hyperbola_(PSF).svg](https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Hyperbola_%28PSF%29.svg/306px-Hyperbola_%28PSF%29.svg.png)
#
# <!-- %%svg
# https://upload.wikimedia.org/wikipedia/commons/0/0e/Hyperbola_%28PSF%29.svg -->

# %%
#@title 双曲線: 90°回転
# %%svg
https://upload.wikimedia.org/wikipedia/commons/3/35/Hyperbel-def-e.svg

# %% [markdown]
# つまり, ここで得られた波の干渉条件は
#
# > 波源 ${\rm S_1, S_2}$ からの **距離の差** によって作られる節(または腹)は, ${\rm S_1, S_2}$ を中心として双曲線上に存在する
#
# ことが分かります.

# %%
#@title 双曲線と波の干渉条件
# %%svg
https://upload.wikimedia.org/wikipedia/commons/1/14/Hyperbel-def-dc.svg

# %% [markdown]
# > Q.  教科書 上巻 p114 の図2.39 の青い実線と波線の様子を確認してください.
